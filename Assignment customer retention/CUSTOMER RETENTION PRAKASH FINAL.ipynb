# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows',None)
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', None)

# %%
df=pd.read_excel('customer_retention_dataset.xlsx')
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                                 110009
# 1                                                 110030
# 2                                                 201308
# 3                                                 132001
# 4                                                 530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.shape
# Out:
# (269, 71)

# %%
t_col=list(df.columns)

# %%
len(t_col)
# Out:
# 71

# %% [markdown]
# Using columns we can see all the 71 column names from the datasheet page.

# %%
categ=[]
for i in t_col:
    if(df[i].dtype!='object'):
        pass
    else:
        categ.append(i)

# %%
categ
# Out:
# ['Gender',
#  'Age',
#  'City',
#  'Online Shopping Duration',
#  'Online purchase in past 1 year',
#  'Mode of internet access',
#  'Device used for internet access',
#  'Screen size of mobile',
#  'Operating System',
#  'Browser',
#  'Channel used for 1st visit',
#  'Online store access post 1st visit',
#  'Time invested to explore and purchase',
#  'Preferred payment option',
#  'Frequency to abandon purchase from a cart',
#  'Reason to abandon purchase from a cart',
#  'Shopping website content readability',
#  'Importance of product comparison content',
#  'Importance of seller and product detail for purchase decision',
#  'Clarity on relevant information for products',
#  'Ease of navigation on website',
#  'Loading and processing speed of website',
#  'Ease of access on GUI of website',
#  'Convenient/Most used payment methods',
#  'On time product delivery',
#  'Empathy towards the customer',
#  'Privacy guarantee of the customer',
# ...

# %% [markdown]
# #### CREATING A LIST OF ALL THE COLUMN NAME ALONG WITH THEIR UNIQUE CATEGORY

# %%
len(categ)
col_name=[]
total=[]
uni_categ=[]

# %%
def uni():
    print("\\\\**********APPENDING  ALL THE UNIQUE VALUES INFORMATION IN EACH CATEGORICAL COLUMN OF THE DATASET IN RESPECTIVE LISTS**********\n\n\n ")
    for i in cat:
        col_name.append(i)
        total.append(len(df[i].unique()))
        uni_categ.append([[j] for j in df[i].unique()])
uni()
# Out:
# \\**********APPENDING  ALL THE UNIQUE VALUES INFORMATION IN EACH CATEGORICAL COLUMN OF THE DATASET IN RESPECTIVE LISTS**********

# %%
info=pd.DataFrame({'COLUMN_NAME':col_name,"TOTAL UNIQUE CATEGORIESIN IN THAT COLUMN":total,"NAME OF UNIQUE CATEGORIES":uni_categ})
info
# Out:
#                                                       COLUMN_NAME  \
# 0                                                          Gender
# 1                                                             Age
# 2                                                            City
# 3                                        Online Shopping Duration
# 4                                  Online purchase in past 1 year
# 5                                         Mode of internet access
# 6                                 Device used for internet access
# 7                                           Screen size of mobile
# 8                                                Operating System
# 9                                                         Browser
# 10                                     Channel used for 1st visit
# 11                             Online store access post 1st visit
# 12                          Time invested to explore and purchase
# ...

# %%
df.isna().sum() # checking for null values
# Out:
# Gender                                                           0
# Age                                                              0
# City                                                             0
# Pin Code                                                         0
# Online Shopping Duration                                         0
# Online purchase in past 1 year                                   0
# Mode of internet access                                          0
# Device used for internet access                                  0
# Screen size of mobile                                            0
# Operating System                                                 0
# Browser                                                          0
# Channel used for 1st visit                                       0
# Online store access post 1st visit                               0
# Time invested to explore and purchase                            0
# ...

# %% [markdown]
# ### As no nulls are present , no to worry about missing data

# %%
# Checking the columns information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Gender                                                         269 non-null    object
#  1   Age                                                            269 non-null    object
#  2   City                                                           269 non-null    object
#  3   Pin Code                                                       269 non-null    int64
#  4   Online Shopping Duration                                       269 non-null    object
#  5   Online purchase in past 1 year                                 269 non-null    object
#  6   Mode of internet access                                        269 non-null    object
# ...

# %% [markdown]
# #### Except PIN code all are object data

# %%
pd.set_option('display.max_columns', None) # show all columns in a dataframe
pd.set_option('display.max_rows', None) # show all rows in a dataframe

# %%
def with_hue(ax, feature, Number_of_categories, hue_categories):
    a = [p.get_height() for p in ax.patches]
    patch = [p for p in ax.patches]
    for i in range(Number_of_categories):
        total = feature.value_counts().values[i]
        for j in range(hue_categories):
            percentage = '{:.1f}%'.format(100 * a[(j*Number_of_categories + i)]/total)
            x = patch[(j*Number_of_categories + i)].get_x() + patch[(j*Number_of_categories + i)].get_width() / 2 - 0.15
            y = patch[(j*Number_of_categories + i)].get_y() + patch[(j*Number_of_categories + i)].get_height() 
            ax.annotate(percentage, (x, y), size = 20)

def without_hue(ax, feature):
    total = len(feature)
    for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_height()/total)
        x = p.get_x() + p.get_width() / 2 - 0.05
        y = p.get_y() + p.get_height()
        ax.annotate(percentage, (x, y), size = 20)

# %%
plt.figure(figsize=(8,8))
ax=sns.countplot(df['Gender'])
without_hue(ax,df['Gender'])
plt.savefig("asd")
plt.show()

# %% [markdown]
# ### In Respondent Female(67.3 %) having  more contribution than male(32.7 %)

# %%
plt.figure(figsize=(10,8))
ax=sns.countplot(df['Age'])
without_hue(ax,df['Age'])
plt.savefig("asf")
plt.show()

# %% [markdown]
# #### People of age group between 30-50 are having more contribution as compared to lessthan 20 and more than 50

# %%
plt.figure(figsize=(8,8))
ax=sns.countplot(df['Gender'],hue=df['Age'])
with_hue(ax,df['Gender'],2,5)
plt.savefig("aaa")
plt.show()

# %% [markdown]
# ### Female showing more shoping adictive than male at every stage of life

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(20, 5))
df.groupby('Gender').size().plot(kind='pie',autopct='%.2f', textprops={'fontsize': 20},
                                  colors=['tomato', 'gold',], ax=ax1)
df.groupby('Age').size().plot(kind='pie', autopct='%.2f', textprops={'fontsize': 20},ax=ax2)
ax1.set_ylabel('Per gender', size=22)
ax2.set_ylabel('Per age group', size=10)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(df['City'],order=df['City'].value_counts().index)
without_hue(ax,df['City'])
plt.savefig("xx")
plt.show()

# %% [markdown]
# #### Respondent are more from Delhi followed by Greater noida and noida

# %%
fig,ax1=plt.subplots(ncols=1,nrows=1,figsize=(10,10))
df.groupby('City').size().plot(kind='pie',autopct='%.2f', textprops={'fontsize': 10},ax=ax1)
ax1.set_ylabel('PER CITY ',loc='top')
plt.tight_layout()
plt.savefig('gig')
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(df['Online Shopping Duration'],hue=df['Gender'])
with_hue(ax,df['Online Shopping Duration'],5,2)
plt.savefig('ioo')
plt.show()

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(df['Mode of internet access'],hue=df['Device used for internet access'])
plt.savefig('ee')
plt.show()

# %% [markdown]
# #### Mobile internet are more comman for online shoping

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(df['Operating System'])
without_hue(ax,df['Operating System'])
plt.savefig('qwe')
plt.show()

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(df['Browser'])
without_hue(ax,df['Browser'])
plt.savefig('qwe')
plt.show()

# %% [markdown]
# #### Google chrome are more commmonly used by the respondent

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90,size=20)
plt.yticks(size=20)
plt.ylabel("count",fontsize=20)
plt.xlabel('Channel used for 1st visit',fontsize=20)
ax=sns.countplot(df['Channel used for 1st visit'],hue=df['Online store access post 1st visit'])
with_hue(ax,df['Channel used for 1st visit'],3,5)
plt.legend(fontsize=20,loc="best")
plt.tight_layout()
plt.savefig('hrh')
plt.show()

# %% [markdown]
# #### Most of the people visit to the website through search engine

# %%
plt.figure(figsize=(20,5))
ax=sns.countplot(df['Time invested to explore and purchase'])
without_hue(ax,df['Time invested to explore and purchase'])
plt.savefig('ff')
plt.show()

# %% [markdown]
# ### Around 70% people are taking time more than 6 min to make purchasing decision

# %%
plt.figure(figsize=(20,5))
ax=sns.countplot(df['Time invested to explore and purchase'],hue=df['Gender'])
plt.savefig('dd')
plt.show()

# %%
plt.figure(figsize=(20,5))
ax=sns.countplot(df['Time invested to explore and purchase'],hue=df['Age'])
plt.savefig('daa')
plt.show()

# %%
plt.figure(figsize=(20,15))
sns.swarmplot(x=df['Frequency to abandon purchase from a cart'],y=df['Reason to abandon purchase from a cart'])
plt.xlabel('Frequency to abandon purchase from a cart',fontsize=20)
plt.ylabel("Reason to abandon purchase from a cart",fontsize=20)
plt.xticks(size=20)
plt.yticks(size=20)
plt.tight_layout()
plt.savefig('tr')
plt.show()

# %% [markdown]
# #### PEOPLE WHO VERY FREQUENTLY ABONDON THE BAG IS BECAUSE THE PROMO CODES ARE NOT WORKING

# %%
plt.figure(figsize=(20,5))
ax=sns.countplot(df['Importance of seller and product detail for purchase decision'])
without_hue(ax,df['Importance of seller and product detail for purchase decision'])
plt.savefig('zaq')
plt.show()

# %% [markdown]
# ####  Completeproductand seller information are important for there purchasing

# %%
plt.figure(figsize=(20,10))
sns.swarmplot(x=df['Loading and processing speed of website'],y=df['Ease of navigation on website'])
plt.xlabel('Loading and processing speed of website	',fontsize=20)
plt.ylabel('Ease of navigation in website',fontsize=20)
plt.xticks(size=20)
plt.yticks(size=20)
plt.tight_layout()
plt.savefig('koko')

plt.show()

# %% [markdown]
# #### MOST OF CUSTOMERS STRONGLY AGREE TO TH FACT THAT SPEED OF WEBSITE AND EASE OF NAVIGATION THROUGH THE WEBSITES HELP IN BETTER PURCHASE DECISION

# %%
plt.figure(figsize=(20,10))
sns.swarmplot(x=df['Convenient/Most used payment methods'],y=df['On time product delivery'])
plt.xlabel("Convenient/Most used payment methods",fontsize=20)
plt.ylabel("On time product delivery",fontsize=20)
plt.xticks(size=20)
plt.yticks(size=20)
plt.tight_layout()
plt.savefig("jaaj")
plt.show()

# %% [markdown]
# ### ONtime product delivery and convinient payment method are important factors

# %%
plt.figure(figsize=(20,10))
plt.xlabel('Empathy towards the customer',fontsize=20)
plt.ylabel("count",fontsize=20)
plt.xticks(size=20)
plt.yticks(size=20)
sns.countplot(df['Empathy towards the customer'],hue=df['Support availability via various means'])
plt.legend(loc="upper right",fontsize=20)
plt.tight_layout()
plt.savefig('poo')
plt.show()

# %%
plt.figure(figsize=(12,5))
ax=sns.countplot(df['Privacy guarantee of the customer'])
plt.xlabel("Privacy guarantee of the customer",fontsize=20)
plt.ylabel("count",fontsize=20)
without_hue(ax,df['Privacy guarantee of the customer'])
plt.savefig("qwe")
plt.show()

# %% [markdown]
# ### Privacy guarantee is very much important for most of the customer

# %%
plt.figure(figsize=(20,10))
sns.swarmplot(x=df['Offers and Discounts on online shopping'],y=df['Enjoyment quotient in online shopping'])
plt.xlabel('Offers and Discounts on online shopping',fontsize=20)
plt.ylabel('Enjoyment quotient in online shopping',fontsize=20)
plt.xticks(size=20)
plt.yticks(size=20)
plt.tight_layout()
plt.savefig('eee')
plt.show()

# %% [markdown]
# Discount offers and customer enjoyment quotient are play a very much important factor for online purchasing

# %%
plt.figure(figsize=(20,5))
ax=sns.countplot(df['Loyalty program benefits'])
without_hue(ax,df['Loyalty program benefits'])
plt.savefig('fg')
plt.show()

# %% [markdown]
# 42.8% people feels very much importance of loyalty benifit

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(df['User satisfaction'])
without_hue(ax,df['User satisfaction'])
plt.savefig('kaka')
plt.show()

# %% [markdown]
# ### User satisfaction are very much important for repurchase

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(df['Frequency of purchase from a seller'])
without_hue(ax,df['Frequency of purchase from a seller'])
plt.savefig('kuy')
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(df['Sense of adventure'])
without_hue(ax,df['Sense of adventure'])
plt.savefig('zxc')
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(df['Fulfill roles from shopping'])
without_hue(ax,df['Fulfill roles from shopping'])
plt.savefig('qaz')
plt.show()

# %%
plt.figure(figsize=(10,5))
ax=sns.countplot(df['Value for money'])
without_hue(ax,df['Value for money'])
plt.savefig('qaz')
plt.show()

# %% [markdown]
# #### AROUND 56.4% OF CUSTOMERS FEELS LIKE THERE IS A VALUE FOR MONEY AND 14.1 PERCENT OF PEOPLE THINKS THATS ITS UNRELATED TO EACH OTHER AND CANT BE LINKED

# %%
fig,ax1=plt.subplots(nrows=1,ncols=1,figsize=(10,5))
df.groupby('List of online shopping websites').size().plot(kind='pie',autopct="%.2f",ax=ax1)
plt.title('% OF MARKET CAPTURED BY DIFFERENT PLATFORMS')
plt.savefig('kkk')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(20,5))
sns.countplot(df['Ease of access on an online website'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# AS WE CAN SEE AMAZON TENDS TO HAVE MORE EASY TO USE WEBSITE AS COMPARED TO PATYM FOLLOWING FLIPKART
# AMAZON ,FLIPKART TOGETHER CONTRIBTES A LOT WHWN IT COMES TO EASY TO USE WEBSITE OR APPLICATION

# %%
fig,ax1=plt.subplots(ncols=1,nrows=1,figsize=(10,10))
df.groupby('Website layout').size().plot(kind='pie',autopct='%.2f', textprops={'fontsize': 10},ax=ax1)
plt.title(' WEBSITE LAYOUT')
plt.savefig('vaw')
plt.tight_layout()
plt.show()

# %% [markdown]
# AROUND 16% OF PEOPLE THINKS THAT AMAZON DOES IT BETTER WHEN IT COMES TO VISAUL APPEALING WEBSITE THEN COMES MYNTRA WHO IS FURTHER FOLLOWED BY FLIPKART
# AND ALMOST 32.34% OF POPULATION BELIEIVES THAT AMAZON AND FLIPAKRT ARE BOTH GOOD WHEN IT COMES TO VISYAL APPEALING WEBSITE AND APPLICATION

# %%
plt.figure(figsize=(30,30))
ax=sns.countplot(x=df['Ease to complete purchase'],order=df['Ease to complete purchase'].value_counts().index)
plt.xlabel('Ease to complete purchase',fontsize=30)
plt.ylabel('count',fontsize=30)
plt.xticks(size=25,rotation=90)
plt.yticks(size=25)
without_hue(ax,df['Ease to complete purchase'])
plt.title('Ease to complete purchase',size=25)
plt.tight_layout()
plt.savefig('qtt')
plt.show()

# %%
AMAZON LEADS THE QUICKINESS TO PAYMENT WHO IS FOLLOWED BY PAYTM AND THEN FLIPKART WHEN WE TALK IN TERMS OF INDIVIDUALITY

# %%
plt.figure(figsize=(30,20))
sns.swarmplot(x=df['Payment option availability'],y=df['Trust worthiness'])
plt.xticks(size=20,rotation=90)
plt.yticks(size=20)
plt.ylabel('Payment option availability',fontsize=30)
plt.xlabel('Trust worthiness',fontsize=30)
plt.tight_layout()
plt.savefig('ghg')
plt.show()

# %% [markdown]
# AMAZON ALONE AND AMAZON AND FLIPKART BOTH COMBINED TOGETHER HAVE ALMOST SAME LEVELS OF PERCIEVED TRUSTORTHINESS WITH INCREASE OF AVAILABILITY OF PAYMENT OPTION

# %%
plt.figure(figsize=(30,15))
sns.swarmplot(x=df['Time to login website on special offer days'],y=df['Time to load media on special offer days'])
plt.xticks(size=20,rotation=90)
plt.yticks(size=20)
plt.ylabel('Time to load media on special offer days',fontsize=30)
plt.xlabel('Time to login website on special offer days',fontsize=30)
plt.show()

# %%
plt.figure(figsize=(30,15))
ax=sns.countplot(x=df['Time to load media on special offer days'],order=df['Time to load media on special offer days'].value_counts().index)
plt.xticks(size=20,rotation=90)
plt.yticks(size=20)
plt.xlabel('Time to load media on special offer days',fontsize=30)
plt.ylabel('count',fontsize=20)
without_hue(ax,df['Time to load media on special offer days'])
plt.tight_layout()
plt.savefig('dfd')
plt.show()

# %%
fig,ax1=plt.subplots(ncols=1,nrows=1,figsize=(10,10))
df.groupby('Delayed product delivery').size().plot(kind='pie',autopct='%.2f', textprops={'fontsize': 10},ax=ax1)
plt.title('DELAY PRODUCT DELIVERY ',fontsize=20)
plt.savefig('oo')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(30,20))
ax=sns.countplot(x=df['Recommendation quotient'],order=df['Recommendation quotient'].value_counts().index)
plt.xticks(size=20,rotation=90)
plt.yticks(size=20)
plt.title('Recommendation quotient',fontsize=40)
plt.ylabel('count',size=30)
plt.xlabel('Recommendation quotient',fontsize=30)
without_hue(ax,df['Recommendation quotient'])
plt.tight_layout()
plt.savefig('rrr')
plt.show()

# %% [markdown]
# Conclusion:
# Based on overall observations, the first 47 features provide insights into how e-tailer is helpful & growing based on customer inputs. The data explained how the online platform has been used more often in which CITY,PIN CODE, AGE GROUP, etc. It also showed that in some factors there is less importance given to contribute to the success of an e-commerce store, so based on that we could remove those factors & keep all the important factors, also we could improve on some factors that influence the online customers repeat purchase intention.
# Apart from the first 47 features, the rest of the features showed which online platform has been used more based on the success factors. Based on the case study for customer activation & retention, Amazon is most reliable and has been fulfilled the customer requirements. After Amazon, data showed Flipkart has been used more for online shopping.
# The case study from Indian e-commerce customers showed Amazon and Flipkart has been used mostly for Online Shopping and most recommended by Friends. So, based on the research factors, Amazon & Flipkart are the e-commerce platform, which are having the combination of both utilitarian and hedonistic values to keep the repeat purchase intention (loyalty) positively.
